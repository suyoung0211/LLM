# %%
from mylib import langchain_tool_weather as ask

# %%
ai_response = ask.ask_weather('서울시 구로구 날씨 알려줘')
# Out:
# 2025-11-10 15:16:59,845 - INFO -
# ...
# 2025-11-10 15:16:59,846 - INFO - 🔵 사용자 질문: 서울시 구로구 날씨 알려줘
# 2025-11-10 15:16:59,846 - INFO - ============================================================
# 2025-11-10 15:17:00,976 - INFO - 날씨 에이전트 설정 완료
# 2025-11-10 15:17:00,977 - INFO - 메시지 초기화 완료
# 2025-11-10 15:17:02,040 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-11-10 15:17:02,090 - INFO - 응답 받음 - tool_calls: 1개
# 2025-11-10 15:17:02,091 - INFO - 도구 호출 발견: 1개
# 2025-11-10 15:17:02,092 - INFO - 도구 실행: get_coordinates
# 2025-11-10 15:17:02,093 - INFO -   - ID: call_zN5JoSqnzDUSemsGOXfo4xQY
# 2025-11-10 15:17:02,094 - INFO -   - Args: {'location': '서울시 구로구'}
# 2025-11-10 15:17:03,471 - INFO - 서울시 구로구의 위도: 37.4951999, 경도: 126.8877000
# 2025-11-10 15:17:03,480 - INFO - ✅도구 실행 결과: 37.4951999,126.8877000...
# 2025-11-10 15:17:03,483 - INFO - 🟢 messages:SystemMessage
# 	HumanMessage
# 	AIMessage
# 	ToolMessage
# ...

# %%
print(f'💬AI : {ai_response}')
# Out:
# 💬AI : 서울시 구로구의 현재 날씨입니다! ☀️
# - 날씨: 맑음
# - 기온: 약 11도
# - 체감온도: 약 8.8도
# - 습도: 24%
#
# 쾌적한 날씨이니 가벼운 옷차림으로 외출하셔도 좋겠어요! 😊

# %%
ai_response = ask.ask_weather(user_question='AI Agents 설명해줘')
print(f'💬AI : {ai_response}')
# Out:
# 2025-11-10 15:03:51,666 - INFO -
# ...
# 2025-11-10 15:03:51,667 - INFO - 🔵 사용자 질문: AI Agents 설명해줘
# 2025-11-10 15:03:51,668 - INFO - ============================================================
# 2025-11-10 15:03:51,675 - INFO - 날씨 에이전트 설정 완료
# 2025-11-10 15:03:51,676 - INFO - 메시지 초기화 완료
# 2025-11-10 15:03:56,741 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 💬AI : AI Agents(인공지능 에이전트)는 특정 목표를 가지고 환경과 상호작용하며 자율적으로 행동하는 인공지능 시스템을 의미합니다. 쉽게 말해, 사람과 비슷하게 주어진 임무를 수행하기 위해 상황을 인식하고, 판단하며, 행동하는 컴퓨터 프로그램이나 알고리즘이라고 할 수 있어요.
#
# 주요 특징을 간단히 설명드릴게요:
# 1. **목표 지향적:** 특정 목적(예: 문제 해결, 정보 수집, 사용자 지원 등)을 가지고 행동합니다.
# 2. **자율성:** 외부 지시 없이 스스로 환경을 감지하고 의사결정을 내립니다.
# 3. **반복적 상호작용:** 환경과 지속적으로 소통하며 상태를 업데이트하고 행동을 수정합니다.
# 4. **적응력:** 학습 기능이 있는 경우 환경 변화에 맞춰 행동을 조정할 수 있습니다.
#
# 대표적인 예로는 챗봇, 자율 주행차, 게임 내 NPC(비플레이어 캐릭터), 스마트 가전 등이 있어요. AI Agents는 복잡한 문제를 분산처리하거나 사람의 일상 업무를 돕는 데 매우 유용하게 활용됩니다. 😊🌟
#
# 필요하시면 더 구체적인 유형이나 작동 원리도 알려드릴게요!

# %%
ai_response = ask.ask_weather(user_question='서울과 도쿄의 날씨 비교해줘')
print(f'💬AI : {ai_response}')
# Out:
# 2025-11-10 15:04:02,304 - INFO -
# ...
# 2025-11-10 15:04:02,305 - INFO - 🔵 사용자 질문: 서울과 도쿄의 날씨 비교해줘
# 2025-11-10 15:04:02,305 - INFO - ============================================================
# 2025-11-10 15:04:02,312 - INFO - 날씨 에이전트 설정 완료
# 2025-11-10 15:04:02,313 - INFO - 메시지 초기화 완료
# 2025-11-10 15:04:03,456 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-11-10 15:04:03,470 - INFO - 응답 받음 - tool_calls: 2개
# 2025-11-10 15:04:03,473 - INFO - 도구 호출 발견: 2개
# 2025-11-10 15:04:03,475 - INFO - 도구 실행: get_coordinates
# 2025-11-10 15:04:03,476 - INFO -   - ID: call_H7lGvSaU3XeL1Pr6TkoMbk8u
# 2025-11-10 15:04:03,478 - INFO -   - Args: {'location': '서울'}
# 2025-11-10 15:04:04,915 - INFO - 서울의 위도: 37.5666791, 경도: 126.9782914
# 2025-11-10 15:04:04,924 - INFO - ✅도구 실행 결과: 37.5666791,126.9782914...
# 2025-11-10 15:04:04,926 - INFO - 도구 실행: get_coordinates
# 2025-11-10 15:04:04,929 - INFO -   - ID: call_fmOBjRD1W71vhlUujlY5o0m0
# ...
