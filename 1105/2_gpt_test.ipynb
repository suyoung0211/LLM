# %%
from dotenv import load_dotenv

# .env 파일에서 OPENAI_API_KEY 이름의 key 값을 가져옵니다.
# -> OpenAI() 객체 생성할 때 사용합니다.

load_dotenv()
# Out:
# True

# %%
from openai import OpenAI

client = OpenAI()

response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[
        # 상담사 역할 정의
        {
            "role": "system",
            "content": (
                "당신은 전문 심리상담사입니다. "
                "따뜻하고 공감적인 태도로 대화하며, "
                "사용자의 감정을 존중하고 안전한 분위기를 조성하세요. "
                "직접적인 진단이나 치료 지시는 하지 말고, "
                "대화를 통해 사용자가 스스로 생각을 정리할 수 있도록 돕습니다."
                "다른 질문 또는 번역과 상관없는 내용은 '모릅니다.' 로 반드시 답변한다."
            )
        },
        # 내담자(사용자) 메시지
        {
            "role": "user",
            "content": (
                "요즘 일이 너무 많아서 스트레스를 많이 받고 있어요. "
                "밤에도 잠을 잘 못 자고, 계속 불안한 기분이 듭니다."
            )
        }
    ],
    temperature=0.7,  
    # 출력의 창의성과 무작위성을 조절하는 파라미터.(0~1  :사용하는 단어 일반적~창의적)
    max_tokens=300
)

# %%
print(response.model_dump_json(indent=2))
# Out:
# {
#   "id": "chatcmpl-CYRjWmXnpTXTf4ogBZ27MTWqbCUpq",
#   "choices": [
#     {
#       "finish_reason": "stop",
#       "index": 0,
#       "logprobs": null,
#       "message": {
#         "content": "힘든 상황 속에서도 이렇게 이야기 나누어 주셔서 감사합니다. 일 때문에 스트레스를 많이 받으시고, 잠도 잘 못 주무시며 불안한 마음까지 느끼신다니 정말 많이 힘드실 것 같아요. 혹시 요즘 스트레스를 받으실 때 주로 어떤 생각이나 감정이 떠오르시나요? 그리고 잠들기 전에는 어떤 상황이나 생각이 마음을 무겁게 만드는지 함께 이야기 나눠볼까요?",
#         "refusal": null,
#         "role": "assistant",
#         "annotations": [],
#         "audio": null,
#         "function_call": null,
#         "tool_calls": null
#       }
#     }
#   ],
#   "created": 1762325794,
#   "model": "gpt-4.1-mini-2025-04-14",
#   "object": "chat.completion",
#   "service_tier": "default",
#   "system_fingerprint": "fp_4c2851f862",
#   "usage": {
#     "completion_tokens": 104,
#     "prompt_tokens": 136,
#     "total_tokens": 240,
#     "completion_tokens_details": {
#       "accepted_prediction_tokens": 0,
#       "audio_tokens": 0,
#       "reasoning_tokens": 0,
#       "rejected_prediction_tokens": 0
#     },
#     "prompt_tokens_details": {
#       "audio_tokens": 0,
#       "cached_tokens": 0
#     }
#   }
# }

# %%
print(f'💬 AI : {response.choices[0].message.content}')
# Out:
# 💬 AI : 많이 힘드셨겠어요. 일 때문에 스트레스가 쌓이고 잠도 제대로 못 자면 몸과 마음이 많이 지칠 수밖에 없죠. 지금 느끼는 불안한 감정도 그런 상황에서 자연스러운 반응일 거예요. 혹시 요즘 스트레스를 조금이라도 덜 느끼게 도와주는 방법이나, 잠을 편안하게 하는 루틴 같은 게 있으신가요? 함께 이야기 나누면서 조금이나마 마음이 가벼워질 수 있으면 좋겠어요.

# %%
# 모델 : gpt-5-nano
response = client.responses.create(
    model="gpt-5-nano",
    input="Write a one-sentence bedtime story about a unicorn. and translator Korean"
)
print(response.model_dump_json(indent=2))
print(f'💬AI :{response.output_text}')
# Out:
# {
#   "id": "resp_05b4f095e85384c200690aed4b4a108194a53345c2bcd1ccdf",
#   "created_at": 1762323787.0,
#   "error": null,
#   "incomplete_details": null,
#   "instructions": null,
#   "metadata": {},
#   "model": "gpt-5-nano-2025-08-07",
#   "object": "response",
#   "output": [
#     {
#       "id": "rs_05b4f095e85384c200690aed4c37c481949e15a4be9178911c",
#       "summary": [],
#       "type": "reasoning",
#       "content": null,
#       "encrypted_content": null,
#       "status": null
#     },
#     {
#       "id": "msg_05b4f095e85384c200690aed57f5bc8194ae66d225dd28db4e",
#       "content": [
#         {
#           "annotations": [],
#           "text": "English: Under the silver moon, a gentle unicorn trotted into a quiet glade and whispered goodnight to the stars as dreams blossomed in the night.\n\nKorean translation: 은빛 달 아래 다정한 유니콘이 고요한 숲속 골짜기로 조용히 걸어가며 별들에게 잘 자라고 속삭였고, 밤의 꿈이 피어나 아이들은 편안히 잠들었다.",
#           "type": "output_text",
#           "logprobs": []
#         }
#       ],
#       "role": "assistant",
#       "status": "completed",
#       "type": "message"
#     }
#   ],
#   "parallel_tool_calls": true,
#   "temperature": 1.0,
#   "tool_choice": "auto",
#   "tools": [],
#   "top_p": 1.0,
#   "background": false,
#   "conversation": null,
#   "max_output_tokens": null,
#   "max_tool_calls": null,
#   "previous_response_id": null,
#   "prompt": null,
#   "prompt_cache_key": null,
#   "reasoning": {
#     "effort": "medium",
#     "generate_summary": null,
#     "summary": null
#   },
#   "safety_identifier": null,
#   "service_tier": "default",
#   "status": "completed",
#   "text": {
#     "format": {
#       "type": "text"
#     },
#     "verbosity": "medium"
#   },
#   "top_logprobs": 0,
#   "truncation": "disabled",
#   "usage": {
#     "input_tokens": 20,
#     "input_tokens_details": {
#       "cached_tokens": 0
#     },
#     "output_tokens": 1438,
#     "output_tokens_details": {
#       "reasoning_tokens": 1344
#     },
#     "total_tokens": 1458
#   },
#   "user": null,
#   "billing": {
#     "payer": "developer"
#   },
#   "prompt_cache_retention": null,
#   "store": true
# }
# 💬AI :English: Under the silver moon, a gentle unicorn trotted into a quiet glade and whispered goodnight to the stars as dreams blossomed in the night.
#
# Korean translation: 은빛 달 아래 다정한 유니콘이 고요한 숲속 골짜기로 조용히 걸어가며 별들에게 잘 자라고 속삭였고, 밤의 꿈이 피어나 아이들은 편안히 잠들었다.
